# %%
#!/usr/bin/env python
import ROOT as ROOT
import os
import random
import sys, optparse
from array import array
import math
import getpass
import socket
import json

def SetCanvas():
    # CMS inputs
    # -------------
    H_ref = 1000;
    W_ref = 1000;
    W = W_ref
    H  = H_ref
    T = 0.08*H_ref
    B = 0.21*H_ref
    L = 0.12*W_ref
    R = 0.08*W_ref
    # --------------
    c1 = ROOT.TCanvas("c2","c2",0,0,1500,1500)
    c1.SetFillColor(0)
    c1.SetBorderMode(0)
    c1.SetFrameFillStyle(0)
    c1.SetFrameBorderMode(0)
    c1.SetLeftMargin( L/W )
    c1.SetRightMargin( R/W )
    c1.SetTopMargin( T/H )
    c1.SetBottomMargin( B/H )
    c1.SetTickx(0)
    c1.SetTicky(0)
    c1.SetTickx(0)
    c1.SetTicky(0)
    c1.SetGridy(0)
    c1.SetGridx(0)
    return c1

def CreateLegend(x1, y1, x2, y2, header):

    leg = ROOT.TLegend(x1, x2, y1, y2)
    leg.SetFillColor(0)
    leg.SetFillStyle(3002)
    leg.SetBorderSize(0)
    leg.SetHeader(header)
    return leg

def CustomiseHistogram(h, titleX, titleY, color,lineStyle,title):
    h.SetMarkerColor(color)
    h.SetMarkerSize(1.0)
    h.SetLineColor(color)
    h.SetLineWidth(2)
    h.SetLineStyle(lineStyle)
    h.GetXaxis().SetLabelSize(0.035)
    h.GetYaxis().SetTitle(titleY)
    h.GetXaxis().SetTitle(titleX)
    h.GetYaxis().SetTitleOffset(1.4)
    h.GetYaxis().SetRange(0,1)
    h.GetXaxis().SetTitleOffset(1.1)
    h.SetTitle(title)
    h.Scale(1/(h.Integral()));
    return

def CustomiseHistogram_(h, titleX, titleY, color,lineStyle,title):
    h.SetMarkerColor(color)
    h.SetMarkerSize(1.0)
    h.SetLineColor(color)
    h.SetLineWidth(2)
    h.SetLineStyle(lineStyle)
    h.GetXaxis().SetLabelSize(0.02)
    h.GetYaxis().SetTitle(titleY)
    h.GetXaxis().SetTitle(titleX)
    h.GetYaxis().SetTitleOffset(1.4)
    h.GetXaxis().SetTitleOffset(1.)
    h.SetTitle(title)
    h.Integral();
    return h.Integral()


def drawHisto(h,draw='hist'):
    h.Draw(draw)
    return


def AddText(txt):
    texcms = ROOT.TLatex(-20.0, 50.0, txt)
    texcms.SetNDC()
    texcms.SetTextAlign(12)
    texcms.SetX(0.15)
    texcms.SetY(0.94)
    texcms.SetTextSize(0.035)
    texcms.SetTextSizePixels(22)
    return texcms

def AddTextCat(cat):
    texCat = ROOT.TLatex(-20.0, 50.0, cat)
    texCat.SetNDC()
    texCat.SetTextAlign(12)
    texCat.SetX(0.80)
    texCat.SetY(0.94)
    texCat.SetTextFont(40)
    texCat.SetTextSize(0.02)
    texCat.SetTextSizePixels(22)
    return texCat
# Out:
# Welcome to JupyROOT 6.14/02

# %%
ROOT.gStyle.SetOptTitle(0)
ROOT.gStyle.SetOptStat(0)
ROOT.gROOT.SetBatch(True)
myHistosa=[]
myHistos_stra=[]
myHistosaa=[]
myHistos_straa=[]
rootFile_addJET0=ROOT.TFile('Output_TT_TuneCUETP8M2T4_13TeV-powheg-pythia8.root')
rootFile_addJET_gt1=ROOT.TFile('Output_TT_TuneCUETP8M2T4_13TeV-powheg-pythia8.root')


for cat in ['1l','2l',]:
    for reg in ['1e1b','1e2b','1mu1b','1mu2b','1mu1e1b','1mu1e2b']:
        for metrec in ['hadrecoil']:
            exec("h_reg_"+reg+"_"+metrec+"_"+cat+" = rootFile.Get('h_reg_"+reg+"_"+metrec+"_')")
            exec("myHistosaa.append(h_reg_"+reg+"_"+metrec+"_"+cat+")")
            exec("myHistos_straa.append('h_reg_"+reg+"_"+metrec+"_"+cat+"')")

h_total=rootFile.Get('h_total')
htotal=CustomiseHistogram_(h_total, '', '# Events', ROOT.kRed, 1,'h_total')
#print (myHistosaa)

titlehist={}
for shist,hist in zip(myHistos_stra,myHistosa):
    titlehist.update({hist : shist.split('_')[2]+'_'+shist.split('_')[-1]})
# Out:
# h_reg_1e1b_hadrecoil_1l
# h_reg_1e2b_hadrecoil_1l
# h_reg_1mu1b_hadrecoil_1l
# h_reg_1mu2b_hadrecoil_1l
# h_reg_1mu1e1b_hadrecoil_1l
# h_reg_1mu1e2b_hadrecoil_1l
# h_met_1l_sr1
# h_met_1l_sr2
# h_reg_1mu1e1b_hadrecoil_2l
# h_reg_1mu1e2b_hadrecoil_2l
# h_met_2l_sr1
# h_met_2l_sr2

# %%
titleX_met = "E_{T}^{miss} (GeV)"
titleX = "Hadronic Recoil (GeV)"
titleY = "# Events"
s_cat=['2b_']
met_had=['MET','hadrecoil']
for s in s_cat:
    #for mh in met_had:
    c1 = SetCanvas()
    colour = 1
    line = 1
    leg = CreateLegend(0.65, 0.91, 0.6, 0.91, "")
    sr1=False
    sr2=False
    for hist in myHistosa:
        #if s in str(hist) and mh in str(hist) and hist.GetEntries()!=0 or :
        if s in str(hist) and hist.GetEntries()!=0 or '_sr2' in str(hist):
            #print (str(hist))
            colour=line
            CustomiseHistogram(hist, titleX, titleY, colour,1,titlehist[hist])
            colour+=1
            line+=1
            if colour==10 or colour==19 : colour=colour+1
            if colour==5: colour=28
            if ('_sr2' in str(hist) and '_2l' in str(hist)):
                hist.Rebin(2)
            else:
                hist.Rebin(2)
            hist.GetXaxis().SetRangeUser(200, 1000)
            drawHisto(hist,"hist same")
            leg.AddEntry(hist, '' , 'l')
    leg.Draw("same")
    txt = 'DM + Heavy Flavor'
    texcms = AddText(txt)
    texCat= AddTextCat("")
    texcms.Draw("same")
    texCat.Draw("same")
    c1.SetLogy()
    c1.Update()
    #c1.SaveAs(s+'_'+l+'_'+mh+'new.pdf')
    c1.SaveAs(s+'had_1l__with1mu1e_new.pdf')
    c1.Close()
    #print ('Done for '+s+'_'+l+' and '+mh)
    #print ('Done for '+s+'_ and '+mh)
# Out:
# Info in <TCanvas::Print>: pdf file 2b_had_1l__with1mu1e_new.pdf has been created
